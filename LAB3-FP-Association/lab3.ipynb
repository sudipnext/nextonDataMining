# %% [markdown]
# # Lab 3: Online Retail FP Growth and Apriori
#
# **Done By:**
# - Name: Sudip Parajuli
# - Roll: PUR077BEI041
# - Faculty: BEI
#
# **Submitted To:**
# - Name: Pukar Karki
# - Department of Electronics and Computer Engineering
# - IOE Purwanchal Campus, Dharan

# %% [markdown]
# # Online Retail

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, fpgrowth, association_rules

# %%
df = pd.read_excel('online_retail/OnlineRetail.xlsx')
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
import pandas as pd 
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import pyfpgrowth

# %%
def run_apriori(df, min_support):
    return apriori(df, min_support=min_support, use_colnames=True)


def generate_rules(frequent_itemsets, min_confidence):
    return association_rules(frequent_itemsets, metric="confidence", min_threshold=min_confidence)


def run_fpgrowth(transactions, min_support):
    patterns = pyfpgrowth.find_frequent_patterns(transactions,
                                                 min_support * len(transactions))
    return patterns

# %%
df = df.dropna(subset=["Description", "CustomerID"])
transactions = df.groupby('InvoiceNo')['Description'].apply(list).values.tolist()

# %%
# One Hot Encoding
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_onehot = pd.DataFrame(te_ary, columns=te.columns_)
df_onehot.head()
# Out:
#     4 PURPLE FLOCK DINNER CANDLES   50'S CHRISTMAS GIFT BAG LARGE  \
# 0                           False                           False
# 1                           False                           False
# 2                           False                           False
# 3                           False                           False
# 4                           False                           False
#
#     DOLLY GIRL BEAKER   I LOVE LONDON MINI BACKPACK  \
# 0               False                         False
# 1               False                         False
# 2               False                         False
# 3               False                         False
# 4               False                         False
#
#     I LOVE LONDON MINI RUCKSACK   NINE DRAWER OFFICE TIDY  \
# 0                         False                     False
# 1                         False                     False
# 2                         False                     False
# 3                         False                     False
# 4                         False                     False
#
#     OVAL WALL MIRROR DIAMANTE    RED SPOT GIFT BAG LARGE  \
# 0                        False                     False
# 1                        False                     False
# 2                        False                     False
# 3                        False                     False
# 4                        False                     False
#
#     SET 2 TEA TOWELS I LOVE LONDON    SPACEBOY BABY GIFT SET  ...  \
# 0                             False                    False  ...
# 1                             False                    False  ...
# 2                             False                    False  ...
# 3                             False                    False  ...
# 4                             False                    False  ...
#
#    ZINC STAR T-LIGHT HOLDER   ZINC SWEETHEART SOAP DISH  \
# 0                      False                      False
# 1                      False                      False
# 2                      False                      False
# 3                      False                      False
# 4                      False                      False
#
#    ZINC SWEETHEART WIRE LETTER RACK  ZINC T-LIGHT HOLDER STAR LARGE  \
# 0                             False                           False
# 1                             False                           False
# 2                             False                           False
# 3                             False                           False
# 4                             False                           False
#
#    ZINC T-LIGHT HOLDER STARS LARGE  ZINC T-LIGHT HOLDER STARS SMALL  \
# 0                            False                            False
# 1                            False                            False
# 2                            False                            False
# 3                            False                            False
# 4                            False                            False
#
#    ZINC TOP  2 DOOR WOODEN SHELF   ZINC WILLIE WINKIE  CANDLE STICK  \
# 0                           False                             False
# 1                           False                             False
# 2                           False                             False
# 3                           False                             False
# 4                           False                             False
#
#    ZINC WIRE KITCHEN ORGANISER  ZINC WIRE SWEETHEART LETTER TRAY
# 0                        False                             False
# 1                        False                             False
# 2                        False                             False
# 3                        False                             False
# 4                        False                             False
#
# [5 rows x 3896 columns]

# %%
# Some Constants
min_support = 0.02
min_confidence = 0.7

# %%
# Using Apriori
frequent_itemsets_apriori = run_apriori(df_onehot, min_support)
frequent_itemsets_apriori
# Out:
#       support                                           itemsets
# 0    0.032988                           (6 RIBBONS RUSTIC CHARM)
# 1    0.021181                  (60 CAKE CASES VINTAGE CHRISTMAS)
# 2    0.029923                      (60 TEATIME FAIRY CAKE CASES)
# 3    0.022758                   (72 SWEETHEART FAIRY CAKE CASES)
# 4    0.036458                       (ALARM CLOCK BAKELIKE GREEN)
# ..        ...                                                ...
# 171  0.020595  (LUNCH BAG RED RETROSPOT, LUNCH BAG SUKI DESIGN )
# 172  0.020460  (PAPER CHAIN KIT VINTAGE CHRISTMAS, PAPER CHAI...
# 173  0.020324  (PINK REGENCY TEACUP AND SAUCER, ROSES REGENCY...
# 174  0.020730  (RED HANGING HEART T-LIGHT HOLDER, WHITE HANGI...
# 175  0.021361  (WOODEN PICTURE FRAME WHITE FINISH, WOODEN FRA...
#
# [176 rows x 2 columns]

# %%
rules_apriori = generate_rules(frequent_itemsets_apriori,
min_confidence)
rules_apriori[['antecedents', 'consequents', 'confidence']]
# Out:
#                             antecedents                          consequents  \
# 0  (GARDENERS KNEELING PAD CUP OF TEA )  (GARDENERS KNEELING PAD KEEP CALM )
# 1      (PINK REGENCY TEACUP AND SAUCER)    (GREEN REGENCY TEACUP AND SAUCER)
# 2     (GREEN REGENCY TEACUP AND SAUCER)   (ROSES REGENCY TEACUP AND SAUCER )
# 3      (PINK REGENCY TEACUP AND SAUCER)   (ROSES REGENCY TEACUP AND SAUCER )
#
#    confidence
# 0    0.725857
# 1    0.796954
# 2    0.759891
# 3    0.763113

# %% [markdown]
# ## Use FP-Growth

# %%
# Example usage
min_support = 0.025
min_confidence = 0.7
patterns_fpgrowth = run_fpgrowth(transactions, min_support)
rules_fpgrowth =pyfpgrowth.generate_association_rules(patterns_fpgrowth,min_confidence)
# Print results or perform further analysis
print("FP-Growth frequent itemsets:\n")
print(patterns_fpgrowth)
print("FP-Growth association rules:\n")
print(rules_fpgrowth)
# Out:
# FP-Growth frequent itemsets:
#
# {('RETROSPOT HEART HOT WATER BOTTLE',): 556, ('LUNCH BAG VINTAGE DOILY ',): 561, ('ANTIQUE SILVER T-LIGHT GLASS',): 564, ('WOOD 2 DRAWER CABINET WHITE FINISH',): 566, ('PACK OF 60 DINOSAUR CAKE CASES',): 569, ('STRAWBERRY CERAMIC TRINKET BOX',): 570, ('PACK OF 20 NAPKINS PANTRY DESIGN',): 570, ('GINGERBREAD MAN COOKIE CUTTER',): 574, ('RED  HARMONICA IN BOX ',): 575, ('PAPER BUNTING RETROSPOT',): 581, ('LOVE BUILDING BLOCK WORD',): 582, ('DOORMAT RED RETROSPOT',): 586, ('HAND OVER THE CHOCOLATE   SIGN ',): 599, ('PLASTERS IN TIN SPACEBOY',): 602, ('HAND WARMER OWL DESIGN',): 605, ('SMALL WHITE HEART OF WICKER',): 609, ("JUMBO BAG 50'S CHRISTMAS ",): 609, ('PLASTERS IN TIN WOODLAND ANIMALS',): 610, ('CHARLOTTE BAG SUKI DESIGN',): 611, ('HANGING HEART JAR T-LIGHT HOLDER',): 611, ('GUMBALL COAT RACK',): 615, ('WOOD BLACK BOARD ANT WHITE FINISH',): 617, ('JUMBO BAG PINK VINTAGE PAISLEY',): 618, ('PINK REGENCY TEACUP AND SAUCER',): 619, ('GREEN REGENCY TEACUP AND SAUCER', 'PINK REGENCY TEACUP AND SAUCER'): 732, ('LUNCH BAG VINTAGE LEAF DESIGN',): 619, ('LUNCH BAG DOLLY GIRL DESIGN',): 621, ('COOK WITH WINE METAL SIGN ',): 624, ('ROUND SNACK BOXES SET OF4 WOODLAND ',): 627, ('ALARM CLOCK BAKELIKE PINK',): 638, ('DOLLY GIRL LUNCH BOX',): 645, ('IVORY KITCHEN SCALES',): 645, ('JUMBO BAG VINTAGE DOILY ',): 647, ('GARDENERS KNEELING PAD CUP OF TEA ',): 656, ('CLOTHES PEGS RETROSPOT PACK 24 ',): 659, ('DOORMAT KEEP CALM AND COME IN',): 662, ('GIN + TONIC DIET METAL SIGN',): 671, ('JUMBO  BAG BAROQUE BLACK WHITE',): 673, ('JUMBO BAG STRAWBERRY',): 677, ('SCOTTIE DOG HOT WATER BOTTLE',): 678, ('LUNCH BAG ALPHABET DESIGN',): 684, ('SET OF 6 SPICE TINS PANTRY DESIGN',): 686, ('PACK OF 60 PINK PAISLEY CAKE CASES',): 692, ('POPCORN HOLDER',): 693, ('60 TEATIME FAIRY CAKE CASES',): 698, ('RED HANGING HEART T-LIGHT HOLDER',): 709, ('HOME BUILDING BLOCK WORD',): 719, ('CHOCOLATE HOT WATER BOTTLE',): 721, ('PLEASE ONE PERSON METAL SIGN',): 723, ('PAPER CHAIN KIT VINTAGE CHRISTMAS',): 725, ('SPACEBOY LUNCH BOX ',): 728, ('VINTAGE SNAP CARDS',): 740, ('JUMBO BAG APPLES',): 747, ('HOT WATER BOTTLE KEEP CALM',): 747, ('SET/20 RED RETROSPOT PAPER NAPKINS ',): 755, ('6 RIBBONS RUSTIC CHARM',): 757, ('GREEN REGENCY TEACUP AND SAUCER',): 761, ('GREEN REGENCY TEACUP AND SAUCER', 'ROSES REGENCY TEACUP AND SAUCER '): 634, ('SET OF 3 REGENCY CAKE TINS',): 764, ('RED RETROSPOT CHARLOTTE BAG',): 767, ('JUMBO BAG ALPHABET',): 775, ('GARDENERS KNEELING PAD KEEP CALM ',): 779, ('JUMBO BAG VINTAGE LEAF',): 788, ('JUMBO STORAGE BAG SUKI',): 800, ('JUMBO SHOPPER VINTAGE RED PAISLEY',): 814, ('SET/5 RED RETROSPOT LID GLASS BOWLS',): 817, ('ALARM CLOCK BAKELIKE GREEN',): 831, ('ALARM CLOCK BAKELIKE GREEN', 'ALARM CLOCK BAKELIKE RED '): 600, ('HEART OF WICKER LARGE',): 835, ('WOODEN FRAME ANTIQUE WHITE ',): 836, ('RETROSPOT TEA SET CERAMIC 11 PC ',): 849, ('VICTORIAN GLASS HANGING T-LIGHT',): 849, ('ROSES REGENCY TEACUP AND SAUCER ',): 854, ('RABBIT NIGHT LIGHT',): 857, ('LUNCH BAG WOODLAND',): 861, ('JAM MAKING SET PRINTED',): 888, ('RECIPE BOX PANTRY YELLOW DESIGN',): 890, ('BAKING SET 9 PIECE RETROSPOT ',): 894, ('SET OF 4 PANTRY JELLY MOULDS',): 902, ('JUMBO BAG PINK POLKADOT',): 903, ('JUMBO BAG PINK POLKADOT', 'JUMBO BAG RED RETROSPOT'): 587, ('WOODEN PICTURE FRAME WHITE FINISH',): 905, ('LUNCH BAG APPLE DESIGN',): 907, ('ALARM CLOCK BAKELIKE RED ',): 932, ('LUNCH BAG SUKI DESIGN ',): 950, ('REX CASH+CARRY JUMBO SHOPPER',): 955, ('JAM MAKING SET WITH JARS',): 974, ('LUNCH BAG PINK POLKADOT',): 977, ('LUNCH BAG PINK POLKADOT', 'LUNCH BAG RED RETROSPOT'): 570, ('HEART OF WICKER SMALL',): 996, ('NATURAL SLATE HEART CHALKBOARD ',): 997, ('LUNCH BAG CARS BLUE',): 1012, ('LUNCH BAG SPACEBOY DESIGN ',): 1021, ("PAPER CHAIN KIT 50'S CHRISTMAS ",): 1029, ('SPOTTY BUNTING',): 1029, ('PACK OF 72 RETROSPOT CAKE CASES',): 1080, ('LUNCH BAG  BLACK SKULL.',): 1126, ('LUNCH BAG  BLACK SKULL.', 'LUNCH BAG RED RETROSPOT'): 577, ('POSTAGE',): 1196, ('SET OF 3 CAKE TINS PANTRY DESIGN ...
# FP-Growth association rules:
#
# {('GREEN REGENCY TEACUP AND SAUCER',): (('ROSES REGENCY TEACUP AND SAUCER ',), 0.8331143232588699), ('PINK REGENCY TEACUP AND SAUCER',): (('GREEN REGENCY TEACUP AND SAUCER',), 1.1825525040387723), ('ROSES REGENCY TEACUP AND SAUCER ',): (('GREEN REGENCY TEACUP AND SAUCER',), 0.7423887587822015), ('ALARM CLOCK BAKELIKE GREEN',): (('ALARM CLOCK BAKELIKE RED ',), 0.7220216606498195)}
